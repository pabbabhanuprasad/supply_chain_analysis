# %% [markdown]
# /Volumes/workspace/default/big_data/shipments.csv
# /Volumes/workspace/default/big_data/gps_logs.csv
# /Volumes/workspace/default/big_data/inventory.csv
# /Volumes/workspace/default/big_data/warehouses.csv

# %%
shipments = spark.read.csv("/Volumes/workspace/default/big_data/shipments.csv", header=True, inferSchema=True)
display(shipments.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
gps_logs = spark.read.csv( "/Volumes/workspace/default/big_data/gps_logs.csv", header=True, inferSchema=True)
display(gps_logs.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
inventory = spark.read.csv("/Volumes/workspace/default/big_data/inventory.csv", header=True, inferSchema=True)
display(inventory.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sku_id</th><th>warehouse_id</th><th>date</th><th>inventory_level</th><th>units_sold</th></tr></thead><tbody><tr><td>SKU0098</td><td>WH038</td><td>2025-01-12</td><td>944</td><td>83</td></tr><tr><td>SKU0471</td><td>WH024</td><td>2025-02-04</td><td>325</td><td>64</td></tr><tr><td>SKU0086</td><td>WH019</td><td>2025-02-23</td><td>614</td><td>74</td></tr><tr><td>SKU0306</td><td>WH014</td><td>2025-01-24</td><td>250</td><td>80</td></tr><tr><td>SKU0273</td><td>WH042</td><td>2025-01-18</td><td>332</td><td>21</td></tr></tbody></table></div>

# %%
warehouses = spark.read.csv("/Volumes/workspace/default/big_data/warehouses.csv", header=True, inferSchema=True)
display(warehouses.head(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>warehouse_id</th><th>warehouse_name</th><th>city</th><th>country</th><th>capacity</th></tr></thead><tbody><tr><td>WH001</td><td>Warehouse_1</td><td>Chennai</td><td>India</td><td>73806</td></tr><tr><td>WH002</td><td>Warehouse_2</td><td>Delhi</td><td>India</td><td>93843</td></tr><tr><td>WH003</td><td>Warehouse_3</td><td>Mumbai</td><td>India</td><td>53295</td></tr><tr><td>WH004</td><td>Warehouse_4</td><td>Chennai</td><td>India</td><td>73088</td></tr><tr><td>WH005</td><td>Warehouse_5</td><td>Mumbai</td><td>India</td><td>119421</td></tr></tbody></table></div>
